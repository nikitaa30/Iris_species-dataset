# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="white") #white background style for seaborn plots
sns.set(style="whitegrid", color_codes=True)

# %%
Iris=pd.read_csv(r"C:\Users\Yatharth Saxena\Downloads\Iris.csv")

# %%
print Iris.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.4           3.9            1.7           0.4  Iris-setosa

# %%
print(Iris.isnull().sum())
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [raw]
# we observe that none of the values are missing in the dataset

# %%
plt.figure(figsize=(20,10))
sns.stripplot(x="Species", y="SepalLengthCm",data=Iris,jitter= True)
plt.show()

# %% [raw]
# we observe that each species lie in a certain range of value for Sepal Length

# %%
plt.figure(figsize=(20,10))
sns.stripplot(x="Species", y="SepalWidthCm",data=Iris,jitter= True)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.stripplot(x="Species", y="PetalLengthCm",data=Iris,jitter= True)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.stripplot(x="Species", y="PetalWidthCm",data=Iris,jitter= True)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.jointplot(x="SepalLengthCm",y="SepalWidthCm",data=Iris,size=10)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.jointplot(x="PetalLengthCm",y="PetalWidthCm",data=Iris,size=10)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.FacetGrid(Iris,hue="Species",size=5).map(plt.scatter,"PetalLengthCm","PetalWidthCm").add_legend()
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.FacetGrid(Iris,hue="Species",size=5).map(plt.scatter,"SepalLengthCm","SepalWidthCm").add_legend()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
col=["PetalLengthCm","PetalWidthCm"]
X=Iris[col]
Y=Iris["Species"]

# %%
from sklearn.svm import SVC
clf=SVC(C=1050,kernel="rbf")
clf.fit(X,Y)
# Out:
# SVC(C=1050, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
clf.score(X,Y)
# Out:
# 0.98333333333333328

# %%
Iris_test=pd.read_csv(r"C:\Users\Yatharth Saxena\Downloads\Iris_test.csv")
W=Iris_test[col]
Z=Iris_test["Species"]
pred=clf.predict(W)

# %%
print pred
# Out:
# ['Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-versicolor' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica']

# %%
clf.score(W,Z)
# Out:
# 0.96666666666666667

# %%
from sklearn.tree import DecisionTreeClassifier
clf2=DecisionTreeClassifier(min_samples_split=2)
clf2.fit(X,Y)
clf2.score(X,Y)
# Out:
# 0.9916666666666667

# %%
pred=clf2.predict(W)

# %%
clf2.score(W,Z)
# Out:
# 0.93333333333333335

# %%
from sklearn.naive_bayes import GaussianNB
clf3=GaussianNB()
clf3.fit(X,Y)
clf3.score(X,Y)
# Out:
# 0.96666666666666667

# %%
clf3.predict(W)

clf3.score(W,Z)
# Out:
# 0.93333333333333335

# %%
from sklearn.neighbors import KNeighborsClassifier
clf4= KNeighborsClassifier()
clf4.fit(X,Y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
clf4.score(X,Y)
# Out:
# 0.96666666666666667

# %%
clf4.predict(W)
clf4.score(W,Z)
# Out:
# 0.96666666666666667

# %%
clf.predict([[3,5]])
# Out:
# array(['Iris-virginica'], dtype=object)
